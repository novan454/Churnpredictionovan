# %% [markdown]
# <a href="https://colab.research.google.com/github/novan454/Churnpredictionovan/blob/main/Best%20Machine%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How To Choose Best Machine Learning?**
# Ini Salah satu cara aku dalam memilih machine learning yang pas aku pakai jika aku bingung dengan pola data, dan disini kita dapat memprioritaskan parameter terbaik yang diinginkan sesuai kebutuhan perusahaan (Novan Surya Putra)

# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 16.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.7/257.7 kB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data
data = get_data('diabetes_latih')
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            8      188             78              0        0  47.9
# 1            7      152             88             44        0  50.0
# 2            2       99             52             15       94  24.6
# 3            1      109             56             21      135  25.2
# 4            2       88             74             19       53  29.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.137   43        1
# 1                     0.337   36        1
# 2                     0.637   21        0
# 3                     0.833   23        0
# 4                     0.229   22        0

# %%
from pycaret.classification import *
s = setup(data, target ='Outcome')
# Out:
# <style type="text/css">
# #T_6f68b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6f68b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f68b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6f68b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f68b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f68b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6f68b_row0_col1" class="data row0 col1" >185</td>
#     </tr>
#     <tr>
#       <th id="T_6f68b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f68b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6f68b_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_6f68b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a674d th {
#   text-align: left;
# }
# ...
